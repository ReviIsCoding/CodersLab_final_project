# %% [markdown]
#  # Opis notatnika
#
#  Ten notatnik inicjuje naszą pracę nad warsztatem końcowym. Naszym zadaniem tutaj jest pobranie udostępnionych nam danych do obszaru roboczego, które w następnym kroku wgramy na naszą bazę danych. Ich obróbka oraz analiza zostanie przeprowadzona w specjalnie do tego celu przygotowanych kolejnych notatnikach.
#
#  Na potrzeby tego warsztatu został stworzony dedykowany serwis API, który dostępny jest pod adresem: https://api-datalab.coderslab.com/api/v2. Dodatkowo udostępniona została dokumentacja, z którą można zapoznać się tutaj: [klik](https://api-datalab.coderslab.com/v2/docs/).
#
#  > Dokumentacja jest czysto techniczna i ma na celu prezentację dostępnych endpointów wraz ze zwracanym typem. W celu przetestowania należy kliknąć przysisk `Authorize`, podać token (dostępny poniżej), a następnie `Try it out!` oraz uzupełnić wymagane pola (parametry requesta).
#
#  Zgodnie z dokumentacją stwierdzamy, że udostępnione zostały nam 4 endpointy:
#  - `airport` - dane o lotnisku,
#  - `weather` - informacje o zarejestrowaniej pogodzie na lotnisku danego dnia,
#  - `aircraft` - dane o samolotach
#  - `flights` - dane o wylotach z danego lotniska per dzień.
#
#  Wszystkie te źródła musimy pobrać, aby być w stanie wykonać całość warsztatu. W celu pobrania informacji, gdzie wymagany jest paramatr `airportId`, posłużymy się listą z pliku `airports.csv`.
#
#  Przy wykonywaniu tego zadania możesz posłużyć się tym tokenem: `iKRsQ8vdqgT903o2vH1rsejOeQ0F7YC9TvutH6Wk`.
#
#  ### Uwagi
#  - Ze względów ćwiczeniowych, konstrukcja poszczególnych endpointów jest różna – w trakcie pracy dokładnie przyjrzyj się, w jaki sposób należy wykonać zapytanie, aby otrzymać odpowiedź.
#  - Pamiętaj o dodaniu `sleep` pomiędzy poszczególnymi wywołaniami endpoint.
#  - Limit wywołań API to 1000/min, zadbaj o nieprzekroczenie tego limitu – w przeciwnym wypadku będzie zwracany błąd 429.

# %% [markdown]
#  # Konfiguracja notatnika

# %% [markdown]
#  Od autorki: Dołączony jest plik konfigurtacyjny środowiska wirutalnego, aby można było wykonać całe zadanie w odpowiednio przygotowanym środowisku. Należy najpierw aktywować środowisko robocze.

# %%
# Tutaj odtwórz i aktywuj środowisko robocze

# %% [markdown]
#  Tutaj zaimportuj wymagane biblioteki

# %%
import requests
import csv
import pandas as pd
import datetime
from dateutil.relativedelta import relativedelta
from time import sleep

# %% [markdown]
#  Tutaj zdefiniuj paramatry połączenia do API

# %%
# klucz
def get_api_key(file_path):
    with open(file_path, 'r') as file:
        api_key = file.read().strip()
    
    return api_key


path_api = "../API_KEY.txt"  # ścieżka do pliku

API_KEY = get_api_key(path_api)  #pobranie klucza

# %%
# adres API bez endpointów
URL = 'https://api-datalab.coderslab.com/api/v2'

# %%
# funkcja składająca URL do endopointu Airport
def get_airport_URL(airport_id):
    return f'{URL}/airport/{airport_id}'

# %% [markdown]
#  Tutaj wczytaj plik `airports.csv` i dostosuj do dalszych kroków w celu pobierania z kolejnych endpointów. Lista lotnisk jest dostępna w kolumnie `origin_airport_id`.

# %%
airport_file_path = "../data/airports.csv"
airports_list = []
with open(airport_file_path, newline="") as my_file:
    a_ids = csv.reader(my_file)
    next(a_ids)
    for line in a_ids:
        for element in line:
            airports_list.append(element)

# %%
print(airports_list[:10])
# Out:
# ['10874', '11233', '13360', '15008', '11638', '14150', '15323', '14814', '12007', '11337']

# %%
# sprawdzam, czy nie powtarzają sie elementy
if len(set(airports_list)) < len(airports_list):
    print("W liście są powtórzone elementy.")
else:
    print("W liście nie ma powtórzonych elementów.")
# Out:
# W liście nie ma powtórzonych elementów.

# %% [markdown]
# Notatka: Dobrą praktyką na przyszłość (z biznesowego punktu widzenia) byłoby tutaj dodanie mechanizmu sprawdzającego czy dane, które chcemy pobrać z APi są już w bazie (już pobrane) - żeby przy kolejnym wywołaniu kodu np. w następnym cyklu o innych datach krańcowych, nie pobierało tego, co już w bazie jest, ale sprawdzało, czy nie doszły nowe dane. Może być przecież tak, że dla jakiegoś id zaczęto zbierać dane w późniejszym czasie, więc nie będzie wszystkich, ale powinny być uwzględnione w końcowym raporcie. Zależy od wymagań klienta biznesowego.

# %% [markdown]
#  # Pobieranie `Airport`
#  Zapoznaj się z dokumentacją endpointu `airport`, a następnie pobierz dane dot. poszczególnych lotnisk. Wyniki tego kroku zapisz do ramki `airport_df`, a następnie zapisz do pliku `csv`.
#
#  ### Wskazówki
#  - Nie wszystkie lotniska dostępne w pliku `airports.csv`, są dostępne w endpoint. Zadbaj o odpowiednie obsłużenie takiej sytuacji,
#  - Do skonwertowania wyników przydatna może okazać się metoda `Pandas` - [from_records](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.from_records.html),
#  - Artykuł LMS: `Python - analiza danych > Dzień 4 - API > Uwierzytelnianie`
#  - Artykuł LMS: `Python - analiza danych > Przygotowanie do zjazdu 2`

# %% [markdown]
#  Tutaj pobierz dane z endpoint'u `airport`

# %%
# na próbę pobranie jednego elementu
response = requests.get(get_airport_URL(11638),headers={'authorization':API_KEY})
if response.ok == True:
    print(response.json())
else:
    print("Bad request")
# Out:
# {'ORIGIN_AIRPORT_ID': 11638, 'DISPLAY_AIRPORT_NAME': 'Fresno Air Terminal', 'ORIGIN_CITY_NAME': 'Fresno, CA', 'NAME': 'FRESNO YOSEMITE INTERNATIONAL, CA US'}

# %%
def call_airport_API(airport_id):
    response = requests.get(get_airport_URL(airport_id),headers={'authorization':API_KEY})
    if response.ok == True:
        return (response.json())  # tu ma zwracać słownik, który będziemy zapisywać
    else:
        return None  # tu ma zwracać None

# %%
# # Teraz zrobimy pętlę, która będzie dodawać słowniki dla każdego lotniska do listy, jeśli danego id nie ma w endpointcie to będzie 'continue'. 
# Po zrobieniu listy całą ją zapiszemy do df za pomocą pandas.DataFrame.from_records

# %%
airport_responses = []  # lista słowników z danymi lotnisk
missing_airports = []  # na wszelki wypadek tworzę listę lotnisk, których brakuje w API
for item in airports_list:
    airport_dict = call_airport_API(item)
    if airport_dict is None:
        missing_airports.append(item)  # dodaje lotnisko do listy brakujących
    else:
        airport_responses.append(airport_dict)  # dodaje słownik dla lotniska do listy lotnisk

# %%
print(airport_responses[:5])
# Out:
# [{'ORIGIN_AIRPORT_ID': 11638, 'DISPLAY_AIRPORT_NAME': 'Fresno Air Terminal', 'ORIGIN_CITY_NAME': 'Fresno, CA', 'NAME': 'FRESNO YOSEMITE INTERNATIONAL, CA US'}, {'ORIGIN_AIRPORT_ID': 13342, 'DISPLAY_AIRPORT_NAME': 'General Mitchell Field', 'ORIGIN_CITY_NAME': 'Milwaukee, WI', 'NAME': 'MILWAUKEE MITCHELL AIRPORT, WI US'}, {'ORIGIN_AIRPORT_ID': 13244, 'DISPLAY_AIRPORT_NAME': 'Memphis International', 'ORIGIN_CITY_NAME': 'Memphis, TN', 'NAME': 'MEMPHIS INTERNATIONAL AIRPORT, TN US'}, {'ORIGIN_AIRPORT_ID': 15096, 'DISPLAY_AIRPORT_NAME': 'Syracuse Hancock International', 'ORIGIN_CITY_NAME': 'Syracuse, NY', 'NAME': 'SYRACUSE HANCOCK INTERNATIONAL AIRPORT, NY US'}, {'ORIGIN_AIRPORT_ID': 10397, 'DISPLAY_AIRPORT_NAME': 'Atlanta Municipal', 'ORIGIN_CITY_NAME': 'Atlanta, GA', 'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US'}]

# %%
print("Brakujące: ", len(missing_airports))
print("Istniejące: ", len(airport_responses))
print("Wszystkie: ", len(airports_list))
# Out:
# Brakujące:  267
# Istniejące:  97
# Wszystkie:  364

# %%
# metoda .from_records jest ogłoszona jako przestarzała, więc nie będę jej używać, 
# zamiast tego polecane jest po prostu użycie pandas.DataFrame
airport_df = pd.DataFrame(airport_responses)

# %% [markdown]
#  ## Sprawdzenie
#  Uruchom kod poniżej, aby sprawdzić czy ta część została poprawnie wykonana

# %%
airport_df_expected_shape = (97, 4)
assert airport_df_expected_shape == airport_df.shape

# %% [markdown]
#  Tutaj zapisz ramkę `airport_df` do pliku `airport_list.csv`

# %%
airport_df.to_csv(r'..\data\raw\airport_list.csv', index=False)

# %% [markdown]
#  # Pobieranie `Weather`
#  Zapoznaj się z dokumentacją endpotu `Weather`, następnie pobierz dane dotyczące zarejestrowanej pogody na poszczególnych lotniskach. Wyniki zapisz do ramki `weather_df`, a później do pliku `airport_weather.csv`.
#
#  Wskazówki:
#  - Ze względu na wolumen danych, które tutaj się pobiorą, odradzamy zapisywanie danych bezpośrednio do ramki. Rekomendujemy podejście podobne do tego z warsztatu na kursie `Python - analiza danych` - `Dzień 10 - Warsztat > Warsztat > Scrapowanie danych`, czyli stworzenie listy, a następnie przekonwertowanie jej w postać ramki.
#  - Data początkowa danych to `2019-01-01`, zaś data końcowa to `2020-03-31`, czyli 15 miesięcy,
#  - Ze względu na czas, jaki ten krok będzie się wykonywał, warto dodać w pętli instrukcję (lub kilka) `print`, aby monitorować przebieg wykonywania tego kroku.
#  - Przy dodawaniu miesięcy do daty może przydać się metoda [relativedelta](https://www.geeksforgeeks.org/python-get-month-from-year-and-weekday/).

# %%
def call_airport_weather_API(date):
    response = requests.get(f'{URL}/airportWeather?date={date}',headers={'authorization':API_KEY})
    if response.ok == True:
        return response.json() # tu ma zwracać słownik, który będziemy zapisywać
    else:
        print(f"Bad request for date {date}")  # tu ma zwracać None
        return None

# %%
date_for_API = datetime.date(2019, 1, 1)
call_airport_weather_API(date_for_API)  # sprawdzam, czy zadziała format daty
# Out:
# [{'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-01',
#   'AWND': 4.7,
#   'PRCP': 0.14,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 64,
#   'TMAX': 66,
#   'TMIN': 57,
#   'WDF2': 310,
#   'WDF5': 310,
#   'WSF2': 15,
#   'WSF5': 19,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-02',
#   'AWND': 4.92,
#   'PRCP': 0.57,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 56,
#   'TMAX': 59,
#   'TMIN': 49,
#   'WDF2': 70,
#   'WDF5': 50,
#   'WSF2': 12.1,
#   'WSF5': 15,
#   'WT01': 1,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-03',
#   'AWND': 5.37,
#   'PRCP': 0.15,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 52,
#   'TMAX': 55,
#   'TMIN': 51,
#   'WDF2': 340,
#   'WDF5': 330,
#   'WSF2': 15,
#   'WSF5': 18.1,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-04',
#   'AWND': 12.08,
#   'PRCP': 1.44,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 56,
#   'TMAX': 66,
#   'TMIN': 45,
#   'WDF2': 260,
#   'WDF5': 260,
#   'WSF2': 28,
#   'WSF5': 34,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-05',
#   'AWND': 13.42,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 49,
#   'TMAX': 59,
#   'TMIN': 44,
#   'WDF2': 280,
#   'WDF5': 330,
#   'WSF2': 23.9,
#   'WSF5': 33.1},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-06',
#   'AWND': 6.49,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 53,
#   'TMAX': 69,
#   'TMIN': 43,
#   'WDF2': 320,
#   'WDF5': 320,
#   'WSF2': 13,
#   'WSF5': 15},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-07',
#   'AWND': 5.14,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 55,
#   'TMAX': 69,
#   'TMIN': 45,
#   'WDF2': 160,
#   'WDF5': 160,
#   'WSF2': 15,
#   'WSF5': 19},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-08',
#   'AWND': 8.05,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 57,
#   'TMAX': 65,
#   'TMIN': 50,
#   'WDF2': 290,
#   'WDF5': 260,
#   'WSF2': 16.1,
#   'WSF5': 21.9,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-09',
#   'AWND': 17.45,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 50,
#   'TMAX': 56,
#   'TMIN': 39,
#   'WDF2': 320,
#   'WDF5': 320,
#   'WSF2': 28,
#   'WSF5': 34},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-10',
#   'AWND': 13.2,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 38,
#   'TMAX': 45,
#   'TMIN': 30,
#   'WDF2': 330,
#   'WDF5': 320,
#   'WSF2': 23.9,
#   'WSF5': 33.1},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-11',
#   'AWND': 6.93,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 40,
#   'TMAX': 54,
#   'TMIN': 30,
#   'WDF2': 120,
#   'WDF5': 110,
#   'WSF2': 12.1,
#   'WSF5': 15},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-12',
#   'AWND': 12.97,
#   'PRCP': 0.35,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 43,
#   'TMAX': 44,
#   'TMIN': 37,
#   'WDF2': 80,
#   'WDF5': 90,
#   'WSF2': 19.9,
#   'WSF5': 25.1,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-13',
#   'AWND': 8.05,
#   'PRCP': 0.27,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 39,
#   'TMAX': 48,
#   'TMIN': 35,
#   'WDF2': 70,
#   'WDF5': 80,
#   'WSF2': 17,
#   'WSF5': 19.9,
#   'WT01': 1,
#   'WT02': 1},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-14',
#   'AWND': 11.63,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 45,
#   'TMAX': 47,
#   'TMIN': 39,
#   'WDF2': 330,
#   'WDF5': 330,
#   'WSF2': 17,
#   'WSF5': 23},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-15',
#   'AWND': 10.74,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 40,
#   'TMAX': 46,
#   'TMIN': 32,
#   'WDF2': 320,
#   'WDF5': 310,
#   'WSF2': 17,
#   'WSF5': 25.1},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-16',
#   'AWND': 7.61,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 38,
#   'TMAX': 53,
#   'TMIN': 30,
#   'WDF2': 320,
#   'WDF5': 330,
#   'WSF2': 13,
#   'WSF5': 16.1,
#   'WT01': 1,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-17',
#   'AWND': 4.03,
#   'PRCP': 0.1,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 42,
#   'TMAX': 50,
#   'TMIN': 35,
#   'WDF2': 180,
#   'WDF5': 180,
#   'WSF2': 8.9,
#   'WSF5': 13,
#   'WT01': 1,
#   'WT03': 1,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-18',
#   'AWND': 2.91,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 50,
#   'TMAX': 58,
#   'TMIN': 47,
#   'WDF2': 220,
#   'WDF5': 220,
#   'WSF2': 8.1,
#   'WSF5': 10.1,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-19',
#   'AWND': 9.62,
#   'PRCP': 1.22,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 55,
#   'TMAX': 63,
#   'TMIN': 51,
#   'WDF2': 180,
#   'WDF5': 170,
#   'WSF2': 19.9,
#   'WSF5': 28,
#   'WT01': 1,
#   'WT02': 1},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-20',
#   'AWND': 20.36,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 42,
#   'TMAX': 53,
#   'TMIN': 29,
#   'WDF2': 310,
#   'WDF5': 310,
#   'WSF2': 30,
#   'WSF5': 42.9,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-21',
#   'AWND': 8.5,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 31,
#   'TMAX': 44,
#   'TMIN': 22,
#   'WDF2': 340,
#   'WDF5': 320,
#   'WSF2': 21.9,
#   'WSF5': 28},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-22',
#   'AWND': 12.3,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 37,
#   'TMAX': 45,
#   'TMIN': 30,
#   'WDF2': 80,
#   'WDF5': 90,
#   'WSF2': 19.9,
#   'WSF5': 23.9},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-23',
#   'AWND': 12.08,
#   'PRCP': 1.71,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 50,
#   'TMAX': 67,
#   'TMIN': 42,
#   'WDF2': 290,
#   'WDF5': 160,
#   'WSF2': 25.1,
#   'WSF5': 36,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-24',
#   'AWND': 13.42,
#   'PRCP': 0.11,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 48,
#   'TMAX': 54,
#   'TMIN': 34,
#   'WDF2': 310,
#   'WDF5': 310,
#   'WSF2': 33.1,
#   'WSF5': 40,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-25',
#   'AWND': 10.07,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 38,
#   'TMAX': 48,
#   'TMIN': 32,
#   'WDF2': 320,
#   'WDF5': 320,
#   'WSF2': 18.1,
#   'WSF5': 28},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-26',
#   'AWND': 5.82,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 38,
#   'TMAX': 52,
#   'TMIN': 28,
#   'WDF2': 330,
#   'WDF5': 340,
#   'WSF2': 17,
#   'WSF5': 21.9},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-27',
#   'AWND': 2.01,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 42,
#   'TMAX': 51,
#   'TMIN': 33,
#   'WDF2': 320,
#   'WDF5': 300,
#   'WSF2': 8.9,
#   'WSF5': 11},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-28',
#   'AWND': 6.26,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 45,
#   'TMAX': 59,
#   'TMIN': 34,
#   'WDF2': 220,
#   'WDF5': 230,
#   'WSF2': 19.9,
#   'WSF5': 25.9},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-29',
#   'AWND': 12.53,
#   'PRCP': 0.17,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 45,
#   'TMAX': 51,
#   'TMIN': 28,
#   'WDF2': 320,
#   'WDF5': 320,
#   'WSF2': 23.9,
#   'WSF5': 28,
#   'WT01': 1,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-30',
#   'AWND': 9.62,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 32,
#   'TMAX': 44,
#   'TMIN': 24,
#   'WDF2': 290,
#   'WDF5': 300,
#   'WSF2': 23.9,
#   'WSF5': 31.1},
#  {'WT18': None,
#   'STATION': 'USW00013874',
#   'NAME': 'ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPORT, GA US',
#   'DATE': '2019-01-31',
#   'AWND': 2.91,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 37,
#   'TMAX': 53,
#   'TMIN': 27,
#   'WDF2': 280,
#   'WDF5': 300,
#   'WSF2': 8.9,
#   'WSF5': 13},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-01',
#   'AWND': 12.3,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 43,
#   'TMAX': 46,
#   'TMIN': 33,
#   'WDF2': 20,
#   'WDF5': 10,
#   'WSF2': 23,
#   'WSF5': 25.1,
#   'WT01': 1,
#   'WT02': 1},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-02',
#   'AWND': 10.96,
#   'PRCP': 2.16,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 39,
#   'TMAX': 42,
#   'TMIN': 37,
#   'WDF2': 360,
#   'WDF5': 350,
#   'WSF2': 17,
#   'WSF5': 21.9,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-03',
#   'AWND': 6.71,
#   'PRCP': 0.22,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 41,
#   'TMAX': 53,
#   'TMIN': 31,
#   'WDF2': 320,
#   'WDF5': 320,
#   'WSF2': 18.1,
#   'WSF5': 23.9,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-04',
#   'AWND': 3.8,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 44,
#   'TMAX': 67,
#   'TMIN': 29,
#   'WDF2': 310,
#   'WDF5': 310,
#   'WSF2': 13,
#   'WSF5': 16.1},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-05',
#   'AWND': 4.47,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 49,
#   'TMAX': 73,
#   'TMIN': 30,
#   'WDF2': 180,
#   'WDF5': 190,
#   'WSF2': 15,
#   'WSF5': 18.1,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-06',
#   'AWND': 7.83,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 49,
#   'TMAX': 75,
#   'TMIN': 33,
#   'WDF2': 180,
#   'WDF5': 180,
#   'WSF2': 23,
#   'WSF5': 31.1,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-07',
#   'AWND': 7.83,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 67,
#   'TMAX': 77,
#   'TMIN': 57,
#   'WDF2': 190,
#   'WDF5': 200,
#   'WSF2': 18.1,
#   'WSF5': 23.9,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-08',
#   'AWND': 5.82,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 64,
#   'TMAX': 78,
#   'TMIN': 49,
#   'WDF2': 20,
#   'WDF5': 20,
#   'WSF2': 18.1,
#   'WSF5': 21.9,
#   'WT01': 1,
#   'WT02': 1},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-09',
#   'AWND': 12.08,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 58,
#   'TMAX': 63,
#   'TMIN': 41,
#   'WDF2': 20,
#   'WDF5': 10,
#   'WSF2': 21,
#   'WSF5': 25.9},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-10',
#   'AWND': 3.36,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 50,
#   'TMAX': 61,
#   'TMIN': 39,
#   'WDF2': 130,
#   'WDF5': 130,
#   'WSF2': 13,
#   'WSF5': 16.1},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-11',
#   'AWND': 4.25,
#   'PRCP': 0.33,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 53,
#   'TMAX': 62,
#   'TMIN': 41,
#   'WDF2': 150,
#   'WDF5': 140,
#   'WSF2': 15,
#   'WSF5': 19,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-12',
#   'AWND': 9.62,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 58,
#   'TMAX': 63,
#   'TMIN': 41,
#   'WDF2': 330,
#   'WDF5': 320,
#   'WSF2': 19.9,
#   'WSF5': 29.1,
#   'WT01': 1,
#   'WT02': 1},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-13',
#   'AWND': 12.08,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 46,
#   'TMAX': 54,
#   'TMIN': 38,
#   'WDF2': 360,
#   'WDF5': 50,
#   'WSF2': 19.9,
#   'WSF5': 23},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-14',
#   'AWND': 6.26,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 44,
#   'TMAX': 51,
#   'TMIN': 34,
#   'WDF2': 20,
#   'WDF5': 20,
#   'WSF2': 17,
#   'WSF5': 19.9,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-15',
#   'AWND': 3.8,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 49,
#   'TMAX': 52,
#   'TMIN': 47,
#   'WDF2': 180,
#   'WDF5': 180,
#   'WSF2': 13,
#   'WSF5': 14.1},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-16',
#   'AWND': 2.91,
#   'PRCP': 0.05,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 52,
#   'TMAX': 58,
#   'TMIN': 50,
#   'WDF2': 180,
#   'WDF5': 190,
#   'WSF2': 8.1,
#   'WSF5': 10.1,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-17',
#   'AWND': 4.25,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 62,
#   'TMAX': 78,
#   'TMIN': 47,
#   'WDF2': 180,
#   'WDF5': 230,
#   'WSF2': 12.1,
#   'WSF5': 14.1,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-18',
#   'AWND': 9.62,
#   'PRCP': 0.01,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 57,
#   'TMAX': 66,
#   'TMIN': 47,
#   'WDF2': 220,
#   'WDF5': 210,
#   'WSF2': 17,
#   'WSF5': 21.9,
#   'WT01': 1,
#   'WT02': 1},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-19',
#   'AWND': 17.22,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 58,
#   'TMAX': 66,
#   'TMIN': 35,
#   'WDF2': 330,
#   'WDF5': 310,
#   'WSF2': 32,
#   'WSF5': 52.1},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-20',
#   'AWND': 5.82,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 42,
#   'TMAX': 55,
#   'TMIN': 31,
#   'WDF2': 350,
#   'WDF5': 360,
#   'WSF2': 15,
#   'WSF5': 19},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-21',
#   'AWND': 9.62,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 44,
#   'TMAX': 67,
#   'TMIN': 27,
#   'WDF2': 150,
#   'WDF5': 150,
#   'WSF2': 23,
#   'WSF5': 29.1,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-22',
#   'AWND': 12.08,
#   'PRCP': 0.1,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 62,
#   'TMAX': 71,
#   'TMIN': 43,
#   'WDF2': 350,
#   'WDF5': 350,
#   'WSF2': 29.1,
#   'WSF5': 35.1,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-23',
#   'AWND': 12.3,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 49,
#   'TMAX': 57,
#   'TMIN': 30,
#   'WDF2': 340,
#   'WDF5': 330,
#   'WSF2': 30,
#   'WSF5': 38,
#   'WT04': 1},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-24',
#   'AWND': 5.82,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 42,
#   'TMAX': 64,
#   'TMIN': 25,
#   'WDF2': 170,
#   'WDF5': 170,
#   'WSF2': 19.9,
#   'WSF5': 23.9},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-25',
#   'AWND': 4.03,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 47,
#   'TMAX': 61,
#   'TMIN': 31,
#   'WDF2': 160,
#   'WDF5': 150,
#   'WSF2': 13,
#   'WSF5': 17},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-26',
#   'AWND': 5.37,
#   'PRCP': 0.27,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 52,
#   'TMAX': 65,
#   'TMIN': 37,
#   'WDF2': 40,
#   'WDF5': 40,
#   'WSF2': 14.1,
#   'WSF5': 16.1,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-27',
#   'AWND': 4.03,
#   'PRCP': 0.11,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 56,
#   'TMAX': 68,
#   'TMIN': 38,
#   'WDF2': 330,
#   'WDF5': 140,
#   'WSF2': 13,
#   'WSF5': 16.1,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-28',
#   'AWND': 13.42,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 52,
#   'TMAX': 72,
#   'TMIN': 36,
#   'WDF2': 360,
#   'WDF5': 10,
#   'WSF2': 38,
#   'WSF5': 50.1},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-29',
#   'AWND': 12.53,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 48,
#   'TMAX': 50,
#   'TMIN': 36,
#   'WDF2': 10,
#   'WDF5': 10,
#   'WSF2': 30,
#   'WSF5': 36},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-30',
#   'AWND': 4.92,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 45,
#   'TMAX': 55,
#   'TMIN': 36,
#   'WDF2': 150,
#   'WDF5': 140,
#   'WSF2': 13,
#   'WSF5': 17},
#  {'WT18': None,
#   'STATION': 'USW00013904',
#   'NAME': 'AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-31',
#   'AWND': 3.58,
#   'PRCP': 0.01,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 52,
#   'TMAX': 61,
#   'TMIN': 48,
#   'WDF2': 150,
#   'WDF5': 50,
#   'WSF2': 12.1,
#   'WSF5': 13,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-01',
#   'AWND': 12.75,
#   'PRCP': 0.03,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 54,
#   'TMAX': 61,
#   'TMIN': 41,
#   'WDF2': 300,
#   'WDF5': 290,
#   'WSF2': 29.1,
#   'WSF5': 36.9,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-02',
#   'AWND': 3.36,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 43,
#   'TMAX': 45,
#   'TMIN': 37,
#   'WDF2': 360,
#   'WDF5': 10,
#   'WSF2': 10.1,
#   'WSF5': 13},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-03',
#   'AWND': 4.03,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 44,
#   'TMAX': 49,
#   'TMIN': 30,
#   'WDF2': 290,
#   'WDF5': 310,
#   'WSF2': 17,
#   'WSF5': 21.9},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-04',
#   'AWND': 3.58,
#   'PRCP': 0.04,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 37,
#   'TMAX': 48,
#   'TMIN': 28,
#   'WDF2': 60,
#   'WDF5': 200,
#   'WSF2': 10.1,
#   'WSF5': 13,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-05',
#   'AWND': 9.84,
#   'PRCP': 0.02,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 46,
#   'TMAX': 50,
#   'TMIN': 44,
#   'WDF2': 290,
#   'WDF5': 290,
#   'WSF2': 25.9,
#   'WSF5': 32,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-06',
#   'AWND': 10.07,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 47,
#   'TMAX': 54,
#   'TMIN': 35,
#   'WDF2': 310,
#   'WDF5': 290,
#   'WSF2': 23.9,
#   'WSF5': 34},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-07',
#   'AWND': 5.59,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 35,
#   'TMAX': 37,
#   'TMIN': 32,
#   'WDF2': 70,
#   'WDF5': 50,
#   'WSF2': 14.1,
#   'WSF5': 19.9},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-08',
#   'AWND': 2.01,
#   'PRCP': 0.16,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 40,
#   'TMAX': 52,
#   'TMIN': 35,
#   'WDF2': 310,
#   'WDF5': 310,
#   'WSF2': 30,
#   'WSF5': 40,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-09',
#   'AWND': 16.33,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 44,
#   'TMAX': 50,
#   'TMIN': 29,
#   'WDF2': 290,
#   'WDF5': 290,
#   'WSF2': 29.1,
#   'WSF5': 38.9,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-10',
#   'AWND': 19.46,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 32,
#   'TMAX': 37,
#   'TMIN': 27,
#   'WDF2': 290,
#   'WDF5': 290,
#   'WSF2': 30,
#   'WSF5': 40},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-11',
#   'AWND': 8.5,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 30,
#   'TMAX': 38,
#   'TMIN': 24,
#   'WDF2': 310,
#   'WDF5': 310,
#   'WSF2': 19.9,
#   'WSF5': 28},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-12',
#   'AWND': 2.46,
#   'PRCP': 0.16,
#   'SNOW': 1,
#   'SNWD': 0,
#   'TAVG': 28,
#   'TMAX': 35,
#   'TMIN': 23,
#   'WDF2': 80,
#   'WDF5': 70,
#   'WSF2': 8.9,
#   'WSF5': 10.1,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-13',
#   'AWND': 8.28,
#   'PRCP': 0.37,
#   'SNOW': 4,
#   'SNWD': 5,
#   'TAVG': 28,
#   'TMAX': 31,
#   'TMIN': 27,
#   'WDF2': 40,
#   'WDF5': 30,
#   'WSF2': 16.1,
#   'WSF5': 21.9,
#   'WT01': 1,
#   'WT02': 1},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-14',
#   'AWND': 4.25,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 5,
#   'TAVG': 30,
#   'TMAX': 35,
#   'TMIN': 22,
#   'WDF2': 30,
#   'WDF5': 10,
#   'WSF2': 12.1,
#   'WSF5': 19.9},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-15',
#   'AWND': 4.47,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 3,
#   'TAVG': 28,
#   'TMAX': 38,
#   'TMIN': 20,
#   'WDF2': 280,
#   'WDF5': 320,
#   'WSF2': 13,
#   'WSF5': 19},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-16',
#   'AWND': 5.59,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 2,
#   'TAVG': 29,
#   'TMAX': 39,
#   'TMIN': 19,
#   'WDF2': 300,
#   'WDF5': 300,
#   'WSF2': 18.1,
#   'WSF5': 25.9,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-17',
#   'AWND': 6.49,
#   'PRCP': 0.06,
#   'SNOW': 0,
#   'SNWD': 1,
#   'TAVG': 35,
#   'TMAX': 37,
#   'TMIN': 30,
#   'WDF2': 70,
#   'WDF5': 30,
#   'WSF2': 13,
#   'WSF5': 19,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-18',
#   'AWND': 3.58,
#   'PRCP': 0.06,
#   'SNOW': 0,
#   'SNWD': 2,
#   'TAVG': 34,
#   'TMAX': 44,
#   'TMIN': 31,
#   'WDF2': 110,
#   'WDF5': 290,
#   'WSF2': 8.9,
#   'WSF5': 13,
#   'WT01': 1,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-19',
#   'AWND': 7.38,
#   'PRCP': 0.76,
#   'SNOW': 0,
#   'SNWD': 1,
#   'TAVG': 35,
#   'TMAX': 38,
#   'TMIN': 33,
#   'WDF2': 70,
#   'WDF5': 70,
#   'WSF2': 16.1,
#   'WSF5': 19,
#   'WT01': 1,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-20',
#   'AWND': 17.22,
#   'PRCP': 0.24,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 38,
#   'TMAX': 49,
#   'TMIN': 16,
#   'WDF2': 300,
#   'WDF5': 290,
#   'WSF2': 31.1,
#   'WSF5': 45,
#   'WT01': 1,
#   'WT02': 1},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-21',
#   'AWND': 19.01,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 17,
#   'TMAX': 21,
#   'TMIN': 12,
#   'WDF2': 290,
#   'WDF5': 290,
#   'WSF2': 33.1,
#   'WSF5': 45},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-22',
#   'AWND': 4.92,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 20,
#   'TMAX': 33,
#   'TMIN': 11,
#   'WDF2': 300,
#   'WDF5': 290,
#   'WSF2': 13,
#   'WSF5': 15},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-23',
#   'AWND': 5.14,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 36,
#   'TMAX': 54,
#   'TMIN': 27,
#   'WDF2': 210,
#   'WDF5': 200,
#   'WSF2': 18.1,
#   'WSF5': 25.9},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-24',
#   'AWND': 10.51,
#   'PRCP': 1.01,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 49,
#   'TMAX': 57,
#   'TMIN': 31,
#   'WDF2': 280,
#   'WDF5': 270,
#   'WSF2': 29.1,
#   'WSF5': 40,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-25',
#   'AWND': 9.17,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 34,
#   'TMAX': 41,
#   'TMIN': 23,
#   'WDF2': 270,
#   'WDF5': 270,
#   'WSF2': 23.9,
#   'WSF5': 33.1},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-26',
#   'AWND': 2.24,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 28,
#   'TMAX': 38,
#   'TMIN': 18,
#   'WDF2': 110,
#   'WDF5': 120,
#   'WSF2': 10.1,
#   'WSF5': 13},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-27',
#   'AWND': 4.25,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 33,
#   'TMAX': 47,
#   'TMIN': 20,
#   'WDF2': 320,
#   'WDF5': 230,
#   'WSF2': 12.1,
#   'WSF5': 19,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-28',
#   'AWND': 6.04,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 33,
#   'TMAX': 38,
#   'TMIN': 24,
#   'WDF2': 330,
#   'WDF5': 350,
#   'WSF2': 13,
#   'WSF5': 19.9},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-29',
#   'AWND': 6.04,
#   'PRCP': 0.24,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 31,
#   'TMAX': 38,
#   'TMIN': 24,
#   'WDF2': 310,
#   'WDF5': 310,
#   'WSF2': 25.1,
#   'WSF5': 34,
#   'WT01': 1,
#   'WT04': 1},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-30',
#   'AWND': 11.63,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 24,
#   'TMAX': 34,
#   'TMIN': 8,
#   'WDF2': 290,
#   'WDF5': 270,
#   'WSF2': 36.9,
#   'WSF5': 48.1,
#   'WT09': 1},
#  {'WT18': None,
#   'STATION': 'USW00093721',
#   'NAME': 'BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US',
#   'DATE': '2019-01-31',
#   'AWND': 6.04,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 12,
#   'TMAX': 21,
#   'TMIN': 5,
#   'WDF2': 290,
#   'WDF5': 300,
#   'WSF2': 19.9,
#   'WSF5': 23.9},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-01',
#   'AWND': 7.16,
#   'PRCP': 0.01,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 67,
#   'TMAX': 71,
#   'TMIN': 54,
#   'WDF2': 200,
#   'WDF5': 200,
#   'WSF2': 21,
#   'WSF5': 29.1,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-02',
#   'AWND': 5.14,
#   'PRCP': 0.1,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 56,
#   'TMAX': 58,
#   'TMIN': 50,
#   'WDF2': 130,
#   'WDF5': 70,
#   'WSF2': 13,
#   'WSF5': 21.9,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-03',
#   'AWND': 2.68,
#   'PRCP': 0.48,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 52,
#   'TMAX': 56,
#   'TMIN': 49,
#   'WDF2': 140,
#   'WDF5': 60,
#   'WSF2': 8.9,
#   'WSF5': 17,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-04',
#   'AWND': 7.61,
#   'PRCP': 0.87,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 55,
#   'TMAX': 62,
#   'TMIN': 50,
#   'WDF2': 220,
#   'WDF5': 240,
#   'WSF2': 23,
#   'WSF5': 34,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-05',
#   'AWND': 10.51,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 53,
#   'TMAX': 64,
#   'TMIN': 43,
#   'WDF2': 220,
#   'WDF5': 210,
#   'WSF2': 21.9,
#   'WSF5': 32},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-06',
#   'AWND': 4.92,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 53,
#   'TMAX': 69,
#   'TMIN': 38,
#   'WDF2': 190,
#   'WDF5': 170,
#   'WSF2': 8.9,
#   'WSF5': 11},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-07',
#   'AWND': 6.93,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 54,
#   'TMAX': 58,
#   'TMIN': 49,
#   'WDF2': 110,
#   'WDF5': 120,
#   'WSF2': 15,
#   'WSF5': 19.9},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-08',
#   'AWND': 8.95,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 56,
#   'TMAX': 67,
#   'TMIN': 50,
#   'WDF2': 230,
#   'WDF5': 230,
#   'WSF2': 19.9,
#   'WSF5': 25.9,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-09',
#   'AWND': 10.07,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 52,
#   'TMAX': 56,
#   'TMIN': 38,
#   'WDF2': 320,
#   'WDF5': 330,
#   'WSF2': 18.1,
#   'WSF5': 30},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-10',
#   'AWND': 5.59,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 38,
#   'TMAX': 46,
#   'TMIN': 28,
#   'WDF2': 350,
#   'WDF5': 340,
#   'WSF2': 13,
#   'WSF5': 18.1},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-11',
#   'AWND': 5.37,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 36,
#   'TMAX': 47,
#   'TMIN': 25,
#   'WDF2': 120,
#   'WDF5': 40,
#   'WSF2': 12.1,
#   'WSF5': 18.1},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-12',
#   'AWND': 7.38,
#   'PRCP': 0.13,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 39,
#   'TMAX': 41,
#   'TMIN': 33,
#   'WDF2': 30,
#   'WDF5': 80,
#   'WSF2': 13,
#   'WSF5': 21.9,
#   'WT01': 1,
#   'WT04': 1},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-13',
#   'AWND': 7.83,
#   'PRCP': 0.69,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 36,
#   'TMAX': 38,
#   'TMIN': 33,
#   'WDF2': 10,
#   'WDF5': 60,
#   'WSF2': 15,
#   'WSF5': 21,
#   'WT01': 1,
#   'WT06': 1},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-14',
#   'AWND': 4.03,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 39,
#   'TMAX': 48,
#   'TMIN': 35,
#   'WDF2': 30,
#   'WDF5': 70,
#   'WSF2': 8.9,
#   'WSF5': 16.1,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-15',
#   'AWND': 3.13,
#   'PRCP': 0.01,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 43,
#   'TMAX': 48,
#   'TMIN': 34,
#   'WDF2': 210,
#   'WDF5': 290,
#   'WSF2': 8.1,
#   'WSF5': 11,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-16',
#   'AWND': 3.58,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 40,
#   'TMAX': 57,
#   'TMIN': 25,
#   'WDF2': 60,
#   'WDF5': 50,
#   'WSF2': 10.1,
#   'WSF5': 19,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-17',
#   'AWND': 4.92,
#   'PRCP': 0.09,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 42,
#   'TMAX': 49,
#   'TMIN': 35,
#   'WDF2': 90,
#   'WDF5': 80,
#   'WSF2': 12.1,
#   'WSF5': 19,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-18',
#   'AWND': 3.13,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 44,
#   'TMAX': 52,
#   'TMIN': 39,
#   'WDF2': 170,
#   'WDF5': 250,
#   'WSF2': 8.1,
#   'WSF5': 11,
#   'WT01': 1,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-19',
#   'AWND': 7.83,
#   'PRCP': 0.85,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 48,
#   'TMAX': 58,
#   'TMIN': 42,
#   'WDF2': 150,
#   'WDF5': 170,
#   'WSF2': 17,
#   'WSF5': 23,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-20',
#   'AWND': 12.75,
#   'PRCP': 0.03,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 50,
#   'TMAX': 57,
#   'TMIN': 27,
#   'WDF2': 140,
#   'WDF5': 320,
#   'WSF2': 25.9,
#   'WSF5': 34,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-21',
#   'AWND': 5.82,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 29,
#   'TMAX': 37,
#   'TMIN': 19,
#   'WDF2': 350,
#   'WDF5': 90,
#   'WSF2': 14.1,
#   'WSF5': 19.9},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-22',
#   'AWND': 5.82,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 31,
#   'TMAX': 42,
#   'TMIN': 23,
#   'WDF2': 120,
#   'WDF5': 90,
#   'WSF2': 15,
#   'WSF5': 19},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-23',
#   'AWND': 9.4,
#   'PRCP': 0.1,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 40,
#   'TMAX': 62,
#   'TMIN': 33,
#   'WDF2': 170,
#   'WDF5': 180,
#   'WSF2': 25.9,
#   'WSF5': 36.9,
#   'WT01': 1,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-24',
#   'AWND': 13.87,
#   'PRCP': 1.24,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 60,
#   'TMAX': 62,
#   'TMIN': 33,
#   'WDF2': 160,
#   'WDF5': 150,
#   'WSF2': 28,
#   'WSF5': 35.1,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-25',
#   'AWND': 4.7,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 39,
#   'TMAX': 50,
#   'TMIN': 25,
#   'WDF2': 280,
#   'WDF5': 320,
#   'WSF2': 12.1,
#   'WSF5': 16.1},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-26',
#   'AWND': 4.03,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 37,
#   'TMAX': 50,
#   'TMIN': 21,
#   'WDF2': 200,
#   'WDF5': 270,
#   'WSF2': 10.1,
#   'WSF5': 13},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-27',
#   'AWND': 2.46,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 40,
#   'TMAX': 52,
#   'TMIN': 26,
#   'WDF2': 340,
#   'WDF5': 340,
#   'WSF2': 8.1,
#   'WSF5': 10.1,
#   'WT01': 1,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-28',
#   'AWND': 6.71,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 45,
#   'TMAX': 56,
#   'TMIN': 32,
#   'WDF2': 180,
#   'WDF5': 200,
#   'WSF2': 15,
#   'WSF5': 19.9},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-29',
#   'AWND': 8.5,
#   'PRCP': 0.08,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 47,
#   'TMAX': 54,
#   'TMIN': 28,
#   'WDF2': 210,
#   'WDF5': 240,
#   'WSF2': 18.1,
#   'WSF5': 25.9,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-30',
#   'AWND': 7.38,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 33,
#   'TMAX': 47,
#   'TMIN': 21,
#   'WDF2': 220,
#   'WDF5': 260,
#   'WSF2': 19.9,
#   'WSF5': 29.1},
#  {'WT18': None,
#   'STATION': 'USW00013881',
#   'NAME': 'CHARLOTTE DOUGLAS AIRPORT, NC US',
#   'DATE': '2019-01-31',
#   'AWND': 6.93,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 33,
#   'TMAX': 45,
#   'TMIN': 22,
#   'WDF2': 210,
#   'WDF5': 100,
#   'WSF2': 12.1,
#   'WSF5': 19},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-01',
#   'AWND': 5.82,
#   'PRCP': 0,
#   'TMAX': 53,
#   'TMIN': 41,
#   'WDF2': 240,
#   'WDF5': 250,
#   'WSF2': 28,
#   'WSF5': 38.9},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-02',
#   'AWND': 5.82,
#   'PRCP': 0,
#   'TMAX': 44,
#   'TMIN': 39,
#   'WDF2': 270,
#   'WDF5': 270,
#   'WSF2': 17,
#   'WSF5': 23,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-03',
#   'AWND': 3.8,
#   'PRCP': 0,
#   'TMAX': 43,
#   'TMIN': 31,
#   'WDF2': 280,
#   'WDF5': 270,
#   'WSF2': 15,
#   'WSF5': 21.9,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-04',
#   'AWND': 5.82,
#   'PRCP': 0.26,
#   'TMAX': 53,
#   'TMIN': 29,
#   'WDF2': 360,
#   'WDF5': 360,
#   'WSF2': 17,
#   'WSF5': 23,
#   'WT01': 1,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-05',
#   'AWND': 6.93,
#   'PRCP': 0,
#   'TMAX': 52,
#   'TMIN': 35,
#   'WDF2': 220,
#   'WDF5': 260,
#   'WSF2': 14.1,
#   'WSF5': 19.9,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-06',
#   'AWND': 3.8,
#   'PRCP': 0,
#   'TMAX': 53,
#   'TMIN': 30,
#   'WDF2': 40,
#   'WDF5': 50,
#   'WSF2': 10.1,
#   'WSF5': 12.1,
#   'WT01': 1,
#   'WT02': 1},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-07',
#   'AWND': 10.07,
#   'PRCP': 0,
#   'TMAX': 61,
#   'TMIN': 43,
#   'WDF2': 230,
#   'WDF5': 240,
#   'WSF2': 32,
#   'WSF5': 44.1},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-08',
#   'AWND': 15.43,
#   'PRCP': 0,
#   'TMAX': 65,
#   'TMIN': 42,
#   'WDF2': 250,
#   'WDF5': 290,
#   'WSF2': 33.1,
#   'WSF5': 47},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-09',
#   'AWND': 12.75,
#   'PRCP': 0,
#   'TMAX': 43,
#   'TMIN': 23,
#   'WDF2': 270,
#   'WDF5': 270,
#   'WSF2': 25.9,
#   'WSF5': 36,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-10',
#   'AWND': 6.71,
#   'PRCP': 0,
#   'TMAX': 29,
#   'TMIN': 23,
#   'WDF2': 330,
#   'WDF5': 330,
#   'WSF2': 14.1,
#   'WSF5': 19},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-11',
#   'AWND': 4.47,
#   'PRCP': 0,
#   'TMAX': 35,
#   'TMIN': 27,
#   'WDF2': 30,
#   'WDF5': 60,
#   'WSF2': 10.1,
#   'WSF5': 13},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-12',
#   'AWND': 4.7,
#   'PRCP': 0.31,
#   'TMAX': 34,
#   'TMIN': 29,
#   'WDF2': 70,
#   'WDF5': 60,
#   'WSF2': 8.9,
#   'WSF5': 12.1,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-13',
#   'AWND': 8.05,
#   'PRCP': 0.34,
#   'TMAX': 34,
#   'TMIN': 30,
#   'WDF2': 20,
#   'WDF5': 30,
#   'WSF2': 16.1,
#   'WSF5': 19.9,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-14',
#   'AWND': 3.58,
#   'PRCP': 0,
#   'TMAX': 32,
#   'TMIN': 18,
#   'WDF2': 340,
#   'WDF5': 280,
#   'WSF2': 10.1,
#   'WSF5': 17,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-15',
#   'AWND': 5.37,
#   'PRCP': 0,
#   'TMAX': 33,
#   'TMIN': 15,
#   'WDF2': 200,
#   'WDF5': 230,
#   'WSF2': 15,
#   'WSF5': 19,
#   'WT01': 1,
#   'WT02': 1,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-16',
#   'AWND': 4.25,
#   'PRCP': 0.01,
#   'TMAX': 36,
#   'TMIN': 33,
#   'WDF2': 200,
#   'WDF5': 310,
#   'WSF2': 14.1,
#   'WSF5': 21,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-17',
#   'AWND': 2.24,
#   'PRCP': 0.16,
#   'TMAX': 41,
#   'TMIN': 33,
#   'WDF2': 280,
#   'WDF5': 290,
#   'WSF2': 13,
#   'WSF5': 16.1,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-18',
#   'AWND': 5.14,
#   'PRCP': 0,
#   'TMAX': 39,
#   'TMIN': 35,
#   'WDF2': 260,
#   'WDF5': 270,
#   'WSF2': 12.1,
#   'WSF5': 15},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-19',
#   'AWND': 10.51,
#   'PRCP': 1.04,
#   'TMAX': 41,
#   'TMIN': 23,
#   'WDF2': 10,
#   'WDF5': 20,
#   'WSF2': 28,
#   'WSF5': 38,
#   'WT01': 1,
#   'WT02': 1,
#   'WT04': 1,
#   'WT06': 1},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-20',
#   'AWND': 12.53,
#   'PRCP': 0.04,
#   'TMAX': 23,
#   'TMIN': 11,
#   'WDF2': 340,
#   'WDF5': 340,
#   'WSF2': 23,
#   'WSF5': 34,
#   'WT01': 1,
#   'WT02': 1,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-21',
#   'AWND': 5.14,
#   'PRCP': 0,
#   'TMAX': 19,
#   'TMIN': 1,
#   'WDF2': 80,
#   'WDF5': 80,
#   'WSF2': 10.1,
#   'WSF5': 13},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-22',
#   'AWND': 7.38,
#   'PRCP': 0,
#   'TMAX': 44,
#   'TMIN': 13,
#   'WDF2': 180,
#   'WDF5': 180,
#   'WSF2': 18.1,
#   'WSF5': 25.9},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-23',
#   'AWND': 9.62,
#   'PRCP': 0.81,
#   'TMAX': 52,
#   'TMIN': 33,
#   'WDF2': 180,
#   'WDF5': 180,
#   'WSF2': 21.9,
#   'WSF5': 29.1,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-24',
#   'AWND': 11.41,
#   'PRCP': 0.03,
#   'TMAX': 33,
#   'TMIN': 26,
#   'WDF2': 250,
#   'WDF5': 260,
#   'WSF2': 21.9,
#   'WSF5': 29.1,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-25',
#   'AWND': 10.96,
#   'PRCP': 0,
#   'TMAX': 28,
#   'TMIN': 13,
#   'WDF2': 280,
#   'WDF5': 300,
#   'WSF2': 21,
#   'WSF5': 27.1},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-26',
#   'AWND': 10.74,
#   'PRCP': 0,
#   'TMAX': 39,
#   'TMIN': 24,
#   'WDF2': 200,
#   'WDF5': 200,
#   'WSF2': 21,
#   'WSF5': 27.1},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-27',
#   'AWND': 9.62,
#   'PRCP': 0,
#   'TMAX': 39,
#   'TMIN': 21,
#   'WDF2': 240,
#   'WDF5': 210,
#   'WSF2': 21.9,
#   'WSF5': 29.1},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-28',
#   'AWND': 10.07,
#   'PRCP': 0.06,
#   'TMAX': 50,
#   'TMIN': 22,
#   'WDF2': 210,
#   'WDF5': 200,
#   'WSF2': 28,
#   'WSF5': 36.9,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-29',
#   'AWND': 14.32,
#   'PRCP': 0,
#   'TMAX': 25,
#   'TMIN': 17,
#   'WDF2': 230,
#   'WDF5': 220,
#   'WSF2': 23.9,
#   'WSF5': 33.1,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-30',
#   'AWND': 12.75,
#   'PRCP': 0,
#   'TMAX': 17,
#   'TMIN': -1,
#   'WDF2': 270,
#   'WDF5': 270,
#   'WSF2': 28,
#   'WSF5': 36.9,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00093812',
#   'NAME': 'CINCINNATI MUNICIPAL AIRPORT LUNKEN FIELD, OH US',
#   'DATE': '2019-01-31',
#   'AWND': 5.37,
#   'PRCP': 0,
#   'TMAX': 18,
#   'TMIN': -2,
#   'WDF2': 50,
#   'WDF5': 50,
#   'WSF2': 10.1,
#   'WSF5': 13},
#  {'WT18': None,
#   'STATION': 'USW00014820',
#   'NAME': 'CLEVELAND HOPKINS INTERNATIONAL AIRPORT, OH US',
#   'DATE': '2019-01-01',
#   'AWND': 12.3,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 45,
#   'TMAX': 56,
#   'TMIN': 34,
#   'WDF2': 270,
#   'WDF5': 260,
#   'WSF2': 38.9,
#   'WSF5': 51,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00014820',
#   'NAME': 'CLEVELAND HOPKINS INTERNATIONAL AIRPORT, OH US',
#   'DATE': '2019-01-02',
#   'AWND': 8.28,
#   'PRCP': 0.04,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 35,
#   'TMAX': 41,
#   'TMIN': 32,
#   'WDF2': 260,
#   'WDF5': 280,
#   'WSF2': 23,
#   'WSF5': 29.1,
#   'WT01': 1,
#   'WT06': 1},
#  {'WT18': None,
#   'STATION': 'USW00014820',
#   'NAME': 'CLEVELAND HOPKINS INTERNATIONAL AIRPORT, OH US',
#   'DATE': '2019-01-03',
#   'AWND': 11.86,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 34,
#   'TMAX': 36,
#   'TMIN': 31,
#   'WDF2': 270,
#   'WDF5': 290,
#   'WSF2': 23,
#   'WSF5': 29.1,
#   'WT06': 1},
#  {'WT18': None,
#   'STATION': 'USW00014820',
#   'NAME': 'CLEVELAND HOPKINS INTERNATIONAL AIRPORT, OH US',
#   'DATE': '2019-01-04',
#   'AWND': 7.83,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 38,
#   'TMAX': 51,
#   'TMIN': 32,
#   'WDF2': 200,
#   'WDF5': 200,
#   'WSF2': 15,
#   'WSF5': 19.9},
#  {'WT18': None,
#   'STATION': 'USW00014820',
#   'NAME': 'CLEVELAND HOPKINS INTERNATIONAL AIRPORT, OH US',
#   'DATE': '2019-01-05',
#   'AWND': 8.28,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 37,
#   'TMAX': 48,
#   'TMIN': 28,
#   'WDF2': 270,
#   'WDF5': 230,
#   'WSF2': 16.1,
#   'WSF5': 21,
#   'WT01': 1,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00014820',
#   'NAME': 'CLEVELAND HOPKINS INTERNATIONAL AIRPORT, OH US',
#   'DATE': '2019-01-06',
#   'AWND': 9.84,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 40,
#   'TMAX': 44,
#   'TMIN': 34,
#   'WDF2': 280,
#   'WDF5': 270,
#   'WSF2': 19.9,
#   'WSF5': 25.1},
#  {'WT18': None,
#   'STATION': 'USW00014820',
#   'NAME': 'CLEVELAND HOPKINS INTERNATIONAL AIRPORT, OH US',
#   'DATE': '2019-01-07',
#   'AWND': 15.43,
#   'PRCP': 0.05,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 38,
#   'TMAX': 57,
#   'TMIN': 33,
#   'WDF2': 170,
#   'WDF5': 170,
#   'WSF2': 30,
#   'WSF5': 38.9,
#   'WT04': 1},
#  {'WT18': None,
#   'STATION': 'USW00014820',
#   'NAME': 'CLEVELAND HOPKINS INTERNATIONAL AIRPORT, OH US',
#   'DATE': '2019-01-08',
#   'AWND': 15.88,
#   'PRCP': 0.61,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 53,
#   'TMAX': 57,
#   'TMIN': 39,
#   'WDF2': 290,
#   'WDF5': 290,
#   'WSF2': 38,
#   'WSF5': 55.9,
#   'WT01': 1,
#   'WT03': 1,
#   'WT05': 1},
#  {'WT18': None,
#   'STATION': 'USW00014820',
#   'NAME': 'CLEVELAND HOPKINS INTERNATIONAL AIRPORT, OH US',
#   'DATE': '2019-01-09',
#   'AWND': 17.22,
#   'PRCP': 0.11,
#   'SNOW': 1,
#   'SNWD': 1,
#   'TAVG': 33,
#   'TMAX': 40,
#   'TMIN': 24,
#   'WDF2': 290,
#   'WDF5': 290,
#   'WSF2': 25.9,
#   'WSF5': 33.1,
#   'WT01': 1,
#   'WT09': 1},
#  {'WT18': None,
#   'STATION': 'USW00014820',
#   'NAME': 'CLEVELAND HOPKINS INTERNATIONAL AIRPORT, OH US',
#   'DATE': '2019-01-10',
#   'AWND': 12.97,
#   'PRCP': 0.01,
#   'SNOW': 0,
#   'SNWD': 1,
#   'TAVG': 25,
#   'TMAX': 26,
#   'TMIN': 24,
#   'WDF2': 310,
#   'WDF5': 320,
#   'WSF2': 23,
#   'WSF5': 31.1},
#  {'WT18': None,
#   'STATION': 'USW00014820',
#   'NAME': 'CLEVELAND HOPKINS INTERNATIONAL AIRPORT, OH US',
#   'DATE': '2019-01-11',
#   'AWND': 4.25,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 1,
#   'TAVG': 26,
#   'TMAX': 31,
#   'TMIN': 25,
# ...
#   'TMIN': 37,
#   'WDF2': 150,
#   'WDF5': 160,
#   'WSF2': 15,
#   'WSF5': 19.9},
#  {'WT18': None,
#   'STATION': 'USW00093225',
#   'NAME': 'SACRAMENTO METROPOLITAN AIRPORT, CA US',
#   'DATE': '2019-01-15',
#   'AWND': 8.72,
#   'PGTM': 2048,
#   'PRCP': 0.82,
#   'TMAX': 54,
#   'TMIN': 43,
#   'WDF2': 140,
#   'WDF5': 160,
#   'WSF2': 29.1,
#   'WSF5': 40},
#  {'WT18': None,
#   'STATION': 'USW00093225',
#   'NAME': 'SACRAMENTO METROPOLITAN AIRPORT, CA US',
#   'DATE': '2019-01-16',
#   'AWND': 20.8,
#   'PGTM': 1819,
#   'PRCP': 1.62,
#   'TMAX': 58,
#   'TMIN': 52,
#   'WDF2': 150,
#   'WDF5': 140,
#   'WSF2': 38.9,
#   'WSF5': 48.1},
#  {'WT18': None,
#   'STATION': 'USW00093225',
#   'NAME': 'SACRAMENTO METROPOLITAN AIRPORT, CA US',
#   'DATE': '2019-01-17',
#   'AWND': 14.76,
#   'PGTM': 5,
#   'PRCP': 0.03,
#   'TMAX': 59,
#   'TMIN': 51,
#   'WDF2': 190,
#   'WDF5': 200,
#   'WSF2': 25.1,
#   'WSF5': 32},
#  {'WT18': None,
#   'STATION': 'USW00093225',
#   'NAME': 'SACRAMENTO METROPOLITAN AIRPORT, CA US',
#   'DATE': '2019-01-18',
#   'AWND': 4.92,
#   'PGTM': 2136,
#   'PRCP': 0.04,
#   'TMAX': 58,
#   'TMIN': 50,
#   'WDF2': 320,
#   'WDF5': 310,
#   'WSF2': 12.1,
#   'WSF5': 14.1},
#  {'WT18': None,
#   'STATION': 'USW00093225',
#   'NAME': 'SACRAMENTO METROPOLITAN AIRPORT, CA US',
#   'DATE': '2019-01-19',
#   'AWND': 4.25,
#   'PGTM': 1528,
#   'PRCP': 0,
#   'TMAX': 64,
#   'TMIN': 52,
#   'WDF2': 160,
#   'WDF5': 210,
#   'WSF2': 8.9,
#   'WSF5': 13},
#  {'WT18': None,
#   'STATION': 'USW00093225',
#   'NAME': 'SACRAMENTO METROPOLITAN AIRPORT, CA US',
#   'DATE': '2019-01-20',
#   'AWND': 13.87,
#   'PGTM': 1549,
#   'PRCP': 0.03,
#   'TMAX': 63,
#   'TMIN': 47,
#   'WDF2': 230,
#   'WDF5': 220,
#   'WSF2': 25.9,
#   'WSF5': 31.1},
#  {'WT18': None,
#   'STATION': 'USW00093225',
#   'NAME': 'SACRAMENTO METROPOLITAN AIRPORT, CA US',
#   'DATE': '2019-01-21',
#   'AWND': 6.71,
#   'PGTM': 2309,
#   'PRCP': 0,
#   'TMAX': 56,
#   'TMIN': 39,
#   'WDF2': 340,
#   'WDF5': 330,
#   'WSF2': 15,
#   'WSF5': 19},
#  {'WT18': None,
#   'STATION': 'USW00093225',
#   'NAME': 'SACRAMENTO METROPOLITAN AIRPORT, CA US',
#   'DATE': '2019-01-22',
#   'AWND': 10.74,
#   'PGTM': 834,
#   'PRCP': 0,
#   'TMAX': 58,
#   'TMIN': 39,
#   'WDF2': 330,
#   'WDF5': 330,
#   'WSF2': 21,
#   'WSF5': 27.1},
#  {'WT18': None,
#   'STATION': 'USW00093225',
#   'NAME': 'SACRAMENTO METROPOLITAN AIRPORT, CA US',
#   'DATE': '2019-01-23',
#   'AWND': 4.92,
#   'PGTM': 1254,
#   'PRCP': 0,
#   'TMAX': 56,
#   'TMIN': 34,
#   'WDF2': 300,
#   'WDF5': 320,
#   'WSF2': 10.1,
#   'WSF5': 16.1},
#  {'WT18': None,
#   'STATION': 'USW00093225',
#   'NAME': 'SACRAMENTO METROPOLITAN AIRPORT, CA US',
#   'DATE': '2019-01-24',
#   'AWND': 2.24,
#   'PGTM': 1410,
#   'PRCP': 0,
#   'TMAX': 58,
#   'TMIN': 34,
#   'WDF2': 110,
#   'WDF5': 270,
#   'WSF2': 6.9,
#   'WSF5': 8.9},
#  {'WT18': None,
#   'STATION': 'USW00093225',
#   'NAME': 'SACRAMENTO METROPOLITAN AIRPORT, CA US',
#   'DATE': '2019-01-25',
#   'AWND': 3.13,
#   'PGTM': 1138,
#   'PRCP': 0,
#   'TMAX': 62,
#   'TMIN': 36,
#   'WDF2': 340,
#   'WDF5': 340,
#   'WSF2': 8.1,
#   'WSF5': 10.1},
#  {'WT18': None,
#   'STATION': 'USW00093225',
#   'NAME': 'SACRAMENTO METROPOLITAN AIRPORT, CA US',
#   'DATE': '2019-01-26',
#   'AWND': 2.68,
#   'PGTM': 1257,
#   'PRCP': 0,
#   'TMAX': 58,
#   'TMIN': 35,
#   'WDF2': 140,
#   'WDF5': 230,
#   'WSF2': 6.9,
#   'WSF5': 8.1},
#  {'WT18': None,
#   'STATION': 'USW00093225',
#   'NAME': 'SACRAMENTO METROPOLITAN AIRPORT, CA US',
#   'DATE': '2019-01-27',
#   'AWND': 4.47,
#   'PGTM': 1246,
#   'PRCP': 0,
#   'TMAX': 64,
#   'TMIN': 38,
#   'WDF2': 330,
#   'WDF5': 150,
#   'WSF2': 10.1,
#   'WSF5': 16.1},
#  {'WT18': None,
#   'STATION': 'USW00093225',
#   'NAME': 'SACRAMENTO METROPOLITAN AIRPORT, CA US',
#   'DATE': '2019-01-28',
#   'AWND': 2.91,
#   'PGTM': 1323,
#   'PRCP': 0,
#   'TMAX': 62,
#   'TMIN': 43,
#   'WDF2': 190,
#   'WDF5': 240,
#   'WSF2': 6.9,
#   'WSF5': 8.9},
#  {'WT18': None,
#   'STATION': 'USW00093225',
#   'NAME': 'SACRAMENTO METROPOLITAN AIRPORT, CA US',
#   'DATE': '2019-01-29',
#   'AWND': 2.46,
#   'PGTM': 1517,
#   'PRCP': 0,
#   'TMAX': 63,
#   'TMIN': 43,
#   'WDF2': 290,
#   'WDF5': 280,
#   'WSF2': 8.1,
#   'WSF5': 11},
#  {'WT18': None,
#   'STATION': 'USW00093225',
#   'NAME': 'SACRAMENTO METROPOLITAN AIRPORT, CA US',
#   'DATE': '2019-01-30',
#   'AWND': 4.47,
#   'PGTM': 2107,
#   'PRCP': 0,
#   'TMAX': 63,
#   'TMIN': 41,
#   'WDF2': 340,
#   'WDF5': 280,
#   'WSF2': 8.9,
#   'WSF5': 14.1},
#  {'WT18': None,
#   'STATION': 'USW00093225',
#   'NAME': 'SACRAMENTO METROPOLITAN AIRPORT, CA US',
#   'DATE': '2019-01-31',
#   'AWND': 4.47,
#   'PGTM': 128,
#   'PRCP': 0,
#   'TMAX': 64,
#   'TMIN': 44,
#   'WDF2': 140,
#   'WDF5': 280,
#   'WSF2': 8.9,
#   'WSF5': 14.1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-01',
#   'AWND': 3.13,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 2,
#   'TAVG': 17,
#   'TMAX': 23,
#   'TMIN': 6,
#   'WDF2': 290,
#   'WDF5': 140,
#   'WSF2': 8.9,
#   'WSF5': 16.1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-02',
#   'AWND': 5.59,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 2,
#   'TAVG': 16,
#   'TMAX': 25,
#   'TMIN': 11,
#   'WDF2': 140,
#   'WDF5': 140,
#   'WSF2': 10.1,
#   'WSF5': 14.1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-03',
#   'AWND': 5.14,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 2,
#   'TAVG': 19,
#   'TMAX': 30,
#   'TMIN': 13,
#   'WDF2': 10,
#   'WDF5': 10,
#   'WSF2': 8.9,
#   'WSF5': 8.9},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-04',
#   'AWND': 3.58,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 2,
#   'TAVG': 21,
#   'TMAX': 30,
#   'TMIN': 13,
#   'WDF2': 280,
#   'WDF5': 280,
#   'WSF2': 8.9,
#   'WSF5': 8.9,
#   'WT01': 1,
#   'WT03': 1,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-05',
#   'AWND': 2.68,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 2,
#   'TAVG': 21,
#   'TMAX': 30,
#   'TMIN': 13,
#   'WDF2': 300,
#   'WDF5': 300,
#   'WSF2': 8.9,
#   'WSF5': 8.9,
#   'WT01': 1,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-06',
#   'AWND': 6.71,
#   'PRCP': 0.22,
#   'SNOW': 1,
#   'SNWD': 2,
#   'TAVG': 32,
#   'TMAX': 37,
#   'TMIN': 28,
#   'WDF2': 160,
#   'WDF5': 160,
#   'WSF2': 17,
#   'WSF5': 23,
#   'WT01': 1,
#   'WT02': 1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-07',
#   'AWND': 10.74,
#   'PRCP': 0.07,
#   'SNOW': 0,
#   'SNWD': 2,
#   'TAVG': 35,
#   'TMAX': 40,
#   'TMIN': 32,
#   'WDF2': 160,
#   'WDF5': 150,
#   'WSF2': 23.9,
#   'WSF5': 33.1,
#   'WT01': 1,
#   'WT05': 1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-08',
#   'AWND': 2.68,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 2,
#   'TAVG': 33,
#   'TMAX': 39,
#   'TMIN': 27,
#   'WDF2': 290,
#   'WDF5': 300,
#   'WSF2': 10.1,
#   'WSF5': 11,
#   'WT01': 1,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-09',
#   'AWND': 4.03,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 1,
#   'TAVG': 33,
#   'TMAX': 40,
#   'TMIN': 27,
#   'WDF2': 280,
#   'WDF5': 290,
#   'WSF2': 13,
#   'WSF5': 16.1,
#   'WT01': 1,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-10',
#   'AWND': 3.36,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 1,
#   'TAVG': 31,
#   'TMAX': 39,
#   'TMIN': 27,
#   'WDF2': 350,
#   'WDF5': 360,
#   'WSF2': 10.1,
#   'WSF5': 12.1,
#   'WT01': 1,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-11',
#   'AWND': 3.36,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 33,
#   'TMAX': 34,
#   'TMIN': 32,
#   'WDF2': 290,
#   'WDF5': 330,
#   'WSF2': 12.1,
#   'WSF5': 14.1,
#   'WT01': 1,
#   'WT02': 1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-12',
#   'AWND': 4.92,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 32,
#   'TMAX': 33,
#   'TMIN': 29,
#   'WDF2': 320,
#   'WDF5': 320,
#   'WSF2': 8.9,
#   'WSF5': 11,
#   'WT01': 1,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-13',
#   'AWND': 6.71,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 29,
#   'TMAX': 31,
#   'TMIN': 26,
#   'WDF2': 320,
#   'WDF5': 340,
#   'WSF2': 12.1,
#   'WSF5': 16.1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-14',
#   'AWND': 3.8,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 26,
#   'TMAX': 30,
#   'TMIN': 20,
#   'WDF2': 310,
#   'WDF5': 350,
#   'WSF2': 10.1,
#   'WSF5': 13,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-15',
#   'AWND': 3.58,
#   'PRCP': 0.04,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 25,
#   'TMAX': 32,
#   'TMIN': 19,
#   'WDF2': 130,
#   'WDF5': 120,
#   'WSF2': 10.1,
#   'WSF5': 12.1,
#   'WT01': 1,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-16',
#   'AWND': 4.92,
#   'PRCP': 0.04,
#   'SNOW': 0,
#   'SNWD': 1,
#   'TAVG': 31,
#   'TMAX': 44,
#   'TMIN': 28,
#   'WDF2': 180,
#   'WDF5': 180,
#   'WSF2': 17,
#   'WSF5': 23,
#   'WT01': 1,
#   'WT06': 1,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-17',
#   'AWND': 12.3,
#   'PRCP': 0.76,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 42,
#   'TMAX': 46,
#   'TMIN': 36,
#   'WDF2': 170,
#   'WDF5': 170,
#   'WSF2': 25.1,
#   'WSF5': 33.1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-18',
#   'AWND': 4.92,
#   'PRCP': 0.01,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 37,
#   'TMAX': 39,
#   'TMIN': 31,
#   'WDF2': 360,
#   'WDF5': 360,
#   'WSF2': 16.1,
#   'WSF5': 19,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-19',
#   'AWND': 8.72,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 34,
#   'TMAX': 43,
#   'TMIN': 29,
#   'WDF2': 140,
#   'WDF5': 150,
#   'WSF2': 16.1,
#   'WSF5': 19.9},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-20',
#   'AWND': 7.61,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 39,
#   'TMAX': 45,
#   'TMIN': 32,
#   'WDF2': 170,
#   'WDF5': 160,
#   'WSF2': 19.9,
#   'WSF5': 23.9},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-21',
#   'AWND': 13.87,
#   'PRCP': 0.61,
#   'SNOW': 4,
#   'SNWD': 0,
#   'TAVG': 37,
#   'TMAX': 47,
#   'TMIN': 26,
#   'WDF2': 330,
#   'WDF5': 320,
#   'WSF2': 29.1,
#   'WSF5': 33.1,
#   'WT01': 1,
#   'WT09': 1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-22',
#   'AWND': 5.82,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 3,
#   'TAVG': 26,
#   'TMAX': 32,
#   'TMIN': 17,
#   'WDF2': 320,
#   'WDF5': 320,
#   'WSF2': 16.1,
#   'WSF5': 19},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-23',
#   'AWND': 8.5,
#   'PRCP': 0.01,
#   'SNOW': 0,
#   'SNWD': 3,
#   'TAVG': 24,
#   'TMAX': 33,
#   'TMIN': 18,
#   'WDF2': 130,
#   'WDF5': 170,
#   'WSF2': 14.1,
#   'WSF5': 17},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-24',
#   'AWND': 2.91,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 3,
#   'TAVG': 33,
#   'TMAX': 42,
#   'TMIN': 30,
#   'WDF2': 310,
#   'WDF5': 310,
#   'WSF2': 8.9,
#   'WSF5': 11},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-25',
#   'AWND': 4.47,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 2,
#   'TAVG': 35,
#   'TMAX': 43,
#   'TMIN': 27,
#   'WDF2': 160,
#   'WDF5': 160,
#   'WSF2': 10.1,
#   'WSF5': 12.1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-26',
#   'AWND': 4.03,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 1,
#   'TAVG': 32,
#   'TMAX': 41,
#   'TMIN': 25,
#   'WDF2': 280,
#   'WDF5': 350,
#   'WSF2': 10.1,
#   'WSF5': 12.1,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-27',
#   'AWND': 6.04,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 34,
#   'TMAX': 44,
#   'TMIN': 29,
#   'WDF2': 150,
#   'WDF5': 150,
#   'WSF2': 14.1,
#   'WSF5': 17,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-28',
#   'AWND': 5.82,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 34,
#   'TMAX': 41,
#   'TMIN': 26,
#   'WDF2': 310,
#   'WDF5': 310,
#   'WSF2': 16.1,
#   'WSF5': 19,
#   'WT01': 1,
#   'WT08': 1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-29',
#   'AWND': 4.7,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 32,
#   'TMAX': 40,
#   'TMIN': 27,
#   'WDF2': 310,
#   'WDF5': 300,
#   'WSF2': 10.1,
#   'WSF5': 12.1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-30',
#   'AWND': 5.14,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 31,
#   'TMAX': 42,
#   'TMIN': 24,
#   'WDF2': 120,
#   'WDF5': 220,
#   'WSF2': 12.1,
#   'WSF5': 14.1,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00024127',
#   'NAME': 'SALT LAKE CITY INTERNATIONAL AIRPORT, UT US',
#   'DATE': '2019-01-31',
#   'AWND': 3.36,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 33,
#   'TMAX': 47,
#   'TMIN': 26,
#   'WDF2': 300,
#   'WDF5': 320,
#   'WSF2': 12.1,
#   'WSF5': 13,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00012921',
#   'NAME': 'SAN ANTONIO INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-01',
#   'AWND': 10.07,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 45,
#   'TMAX': 52,
#   'TMIN': 38,
#   'WDF2': 20,
#   'WDF5': 20,
#   'WSF2': 17,
#   'WSF5': 23,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00012921',
#   'NAME': 'SAN ANTONIO INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-02',
#   'AWND': 10.29,
#   'PRCP': 0.63,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 41,
#   'TMAX': 48,
#   'TMIN': 37,
#   'WDF2': 100,
#   'WDF5': 100,
#   'WSF2': 25.9,
#   'WSF5': 30,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00012921',
#   'NAME': 'SAN ANTONIO INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-03',
#   'AWND': 8.5,
#   'PRCP': 0.07,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 43,
#   'TMAX': 57,
#   'TMIN': 37,
#   'WDF2': 320,
#   'WDF5': 320,
#   'WSF2': 18.1,
#   'WSF5': 23,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00012921',
#   'NAME': 'SAN ANTONIO INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-04',
#   'AWND': 6.04,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 49,
#   'TMAX': 71,
#   'TMIN': 34,
#   'WDF2': 220,
#   'WDF5': 330,
#   'WSF2': 14.1,
#   'WSF5': 17},
#  {'WT18': None,
#   'STATION': 'USW00012921',
#   'NAME': 'SAN ANTONIO INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-05',
#   'AWND': 5.37,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 52,
#   'TMAX': 72,
#   'TMIN': 34,
#   'WDF2': 160,
#   'WDF5': 170,
#   'WSF2': 12.1,
#   'WSF5': 15},
#  {'WT18': None,
#   'STATION': 'USW00012921',
#   'NAME': 'SAN ANTONIO INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-06',
#   'AWND': 9.17,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 55,
#   'TMAX': 73,
#   'TMIN': 42,
#   'WDF2': 140,
#   'WDF5': 190,
#   'WSF2': 19.9,
#   'WSF5': 27.1},
#  {'WT18': None,
#   'STATION': 'USW00012921',
#   'NAME': 'SAN ANTONIO INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-07',
#   'AWND': 4.92,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 67,
#   'TMAX': 75,
#   'TMIN': 55,
#   'WDF2': 170,
#   'WDF5': 170,
#   'WSF2': 15,
#   'WSF5': 19.9,
#   'WT01': 1},
#  {'WT18': None,
#   'STATION': 'USW00012921',
#   'NAME': 'SAN ANTONIO INTERNATIONAL AIRPORT, TX US',
#   'DATE': '2019-01-08',
#   'AWND': 5.82,
#   'PRCP': 0,
#   'SNOW': 0,
#   'SNWD': 0,
#   'TAVG': 64,
#   'TMAX': 78,
#   'TMIN': 53,
#   'WDF2': 10,
#   'WDF5': 10,
#   'WSF2': 15,
#   'WSF5': 21.9,
#   'WT01': 1,
#   'WT02': 1},
#  ...]

# %%
weather_reports_list = []

for i in range(15):
    weather_report = call_airport_weather_API(date_for_API)
    for element in weather_report:
        weather_reports_list.append(element)
    print(datetime.datetime.now(), " Pobrane dane dla miesiąca: ", date_for_API, f" Obieg pętli: {i}")  #printujemy logi
    date_for_API += relativedelta(months=1)
# Out:
# 2024-03-07 09:06:53.379315  Pobrane dane dla miesiąca:  2019-01-01  Obieg pętli: 0
# 2024-03-07 09:06:54.197918  Pobrane dane dla miesiąca:  2019-02-01  Obieg pętli: 1
# 2024-03-07 09:06:55.032642  Pobrane dane dla miesiąca:  2019-03-01  Obieg pętli: 2
# 2024-03-07 09:06:55.828225  Pobrane dane dla miesiąca:  2019-04-01  Obieg pętli: 3
# 2024-03-07 09:06:56.616652  Pobrane dane dla miesiąca:  2019-05-01  Obieg pętli: 4
# 2024-03-07 09:06:57.402235  Pobrane dane dla miesiąca:  2019-06-01  Obieg pętli: 5
# 2024-03-07 09:06:58.310699  Pobrane dane dla miesiąca:  2019-07-01  Obieg pętli: 6
# 2024-03-07 09:06:59.116435  Pobrane dane dla miesiąca:  2019-08-01  Obieg pętli: 7
# 2024-03-07 09:06:59.905793  Pobrane dane dla miesiąca:  2019-09-01  Obieg pętli: 8
# 2024-03-07 09:07:00.724541  Pobrane dane dla miesiąca:  2019-10-01  Obieg pętli: 9
# 2024-03-07 09:07:01.601470  Pobrane dane dla miesiąca:  2019-11-01  Obieg pętli: 10
# 2024-03-07 09:07:02.476474  Pobrane dane dla miesiąca:  2019-12-01  Obieg pętli: 11
# 2024-03-07 09:07:03.230099  Pobrane dane dla miesiąca:  2020-01-01  Obieg pętli: 12
# 2024-03-07 09:07:03.935409  Pobrane dane dla miesiąca:  2020-02-01  Obieg pętli: 13
# 2024-03-07 09:07:04.652095  Pobrane dane dla miesiąca:  2020-03-01  Obieg pętli: 14

# %%
print(len(weather_reports_list))
# Out:
# 46226

# %%
airport_weather_df = pd.DataFrame(weather_reports_list)

# %% [markdown]
#  ## Sprawdzenie
#  Uruchom kod poniżej, aby sprawdzić, czy ta część została poprawnie wykonana

# %%
airport_weather_df_expected_shape = (46226, 33)
assert airport_weather_df_expected_shape == airport_weather_df.shape

# %% [markdown]
#  ## Zapis do pliku
#  Tutaj zapisz ramkę `weather_df` do pliku `airport_weather.csv` w katalogu `data/raw`

# %%
airport_weather_df.to_csv(r'..\data\raw\airport_weather.csv', index=False)

# %% [markdown]
#  # Pobranie `Aircraft`
#  Zapoznaj się z dokumentacją endpointu `aircraft`, a następnie pobierz dane produkcyjne samolotów. Wyniki zapisz do ramki `aircraft_df`, a następnie zapisz do pliku `aircraft.csv`.

# %%
def call_airport_aircraft_API():
    response = requests.get(f'{URL}/aircraft',headers={'authorization':API_KEY})
    if response.ok == True:
        return response.json() # tu ma zwracać słownik, który będziemy zapisywać
    else:
        print("Bad request")  # tu ma zwracać None
        return None

# %%
planes_list = []
aircraft_info = call_airport_aircraft_API()
for item in aircraft_info:
    planes_list.append(item)

# %%
print(len(planes_list))
# Out:
# 7383

# %%
aircraft_df = pd.DataFrame(planes_list)

# %% [markdown]
#  ## Sprawdzenie
#  Uruchom kod poniżej, aby sprawdzić, czy ta część została poprawnie wykonana

# %%
aircraft_df_expected_shape = (7383, 3)
assert aircraft_df_expected_shape == aircraft_df.shape

# %% [markdown]
#  ## Zapis do pliku
#  Tutaj zapisz ramkę `aircraft_df` do pliku `aircraft.csv` w katalogu `data/raw`

# %%
aircraft_df.to_csv(r'..\data\raw\aircraft.csv', index=False)

# %% [markdown]
#  # Pobranie `Flight`
#  Zapoznaj się z dokumentacją endpointu `flights`, następnie pobierz dane dotyczące ruchu lotniczego. Wyniki zapisz do ramki `flight_df`, a później do pliku `flight.csv`.
#
#  Wskazówki:
#  - Zwróć szczególną uwagę na konstrukcję endpointa,
#  - Ze względu na wolumen danych, które tutaj się pobiorą, odradzamy zapisywanie danych bezpośrednio do ramki. Rekomendujemy podejście podobne do tego, z warsztatu na kursie `Python - analiza danych` - `Dzień 10 - Warsztat > Warsztat > Scrapowanie danych`,
#  - Data początkowa danych to `2019-01-01`, zaś końcowa to `2020-03-31`, czyli 456 dni,
#  - Ze względu na czas, jaki ten krok będzie się wykonywał, warto dodać w pętli instrukcję (lub kilka) `print`, aby monitorować przebieg wykonywania tego kroku,
#  - W przypadku, gdy nie ma dostępnych danych dla danego lotniska, API zwraca kod [204](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/204), w ten sposób możesz pominąć lotniska, dla których dane nie są dostępne,
#  - Pobranie całości danych zajmuje dłuższą chwilę, zanim włączysz pętle dla wszystkich danych, sprawdź pobieranie danych dla jednego, dwóch lotnisk aby uniknąć frustracji.

# %%
# data początkowa:
date_starting = datetime.date(2019, 1, 1)

def change_date_format(input_date):  # funkcja zmieniająca format daty
    return input_date.strftime('%Y-%m')

# %%
# próba dla wewnętrznej pętli (czyli dla jednego lotniska dane z 15 miesięcy)
temp_id = '14814'
def call_flights_by_airportid(temp_id, date_to_chceck):  #wywołanie API dla jednego lotniska i konkretnej daty
    date_formatted = change_date_format(date_to_chceck)
    response = requests.get(f'{URL}/flight?airportId={temp_id}&date={date_formatted}',headers={'authorization':API_KEY})
    if response.status_code == 200:
        print(datetime.datetime.now(), f" Pobrano dane dla lotniska o id: {temp_id} w miesiącu {date_to_chceck}")
        return response.json()
    elif response.status_code == 204:
        print(datetime.datetime.now(), f" Brak danych dla lotniska o id: {temp_id} w miesiącu {date_to_chceck}")
        return None
    else:
        print("Bad request: ", response.status_code)  # tu ma zwracać None
        return None
            
def one_airport_loop(temp_id):  # pętla dla jednego lotniska, wykorzystująca funkcję zdefiniowaną powyżej
    temp_list = []
    date = date_starting
    for i in range(15):
        flights = call_flights_by_airportid(temp_id, date)
        date += relativedelta(months=1)  # zwiększam datę o miesiąc do następnego obiegu pętli
        if flights is None:
            continue
        else:
            temp_list.extend(flights)
    print(datetime.datetime.now(), f"Koniec zadania dla lotniska {temp_id}")
    if len(temp_list) == 0:
        return None
    else:
        return temp_list

# %%
jedno_lotnisko = one_airport_loop(11278)  # sprawdzam działanie swoich funkcji
print(jedno_lotnisko[:5])
# Out:
# 2024-03-07 09:19:48.845789  Pobrano dane dla lotniska o id: 11278 w miesiącu 2019-01-01
# 2024-03-07 09:19:50.790232  Pobrano dane dla lotniska o id: 11278 w miesiącu 2019-02-01
# 2024-03-07 09:19:52.864184  Pobrano dane dla lotniska o id: 11278 w miesiącu 2019-03-01
# 2024-03-07 09:19:55.018750  Pobrano dane dla lotniska o id: 11278 w miesiącu 2019-04-01
# 2024-03-07 09:19:57.231784  Pobrano dane dla lotniska o id: 11278 w miesiącu 2019-05-01
# 2024-03-07 09:19:59.421185  Pobrano dane dla lotniska o id: 11278 w miesiącu 2019-06-01
# 2024-03-07 09:20:01.648831  Pobrano dane dla lotniska o id: 11278 w miesiącu 2019-07-01
# 2024-03-07 09:20:03.701855  Pobrano dane dla lotniska o id: 11278 w miesiącu 2019-08-01
# 2024-03-07 09:20:05.877651  Pobrano dane dla lotniska o id: 11278 w miesiącu 2019-09-01
# 2024-03-07 09:20:08.063483  Pobrano dane dla lotniska o id: 11278 w miesiącu 2019-10-01
# 2024-03-07 09:20:10.178660  Pobrano dane dla lotniska o id: 11278 w miesiącu 2019-11-01
# 2024-03-07 09:20:12.292497  Pobrano dane dla lotniska o id: 11278 w miesiącu 2019-12-01
# 2024-03-07 09:20:14.484835  Pobrano dane dla lotniska o id: 11278 w miesiącu 2020-01-01
# 2024-03-07 09:20:16.532557  Pobrano dane dla lotniska o id: 11278 w miesiącu 2020-02-01
# 2024-03-07 09:20:18.620396  Pobrano dane dla lotniska o id: 11278 w miesiącu 2020-03-01
# 2024-03-07 09:20:18.629464 Koniec zadania dla lotniska 11278
# [{'MONTH': 1, 'DAY_OF_MONTH': 20, 'DAY_OF_WEEK': 7, 'OP_UNIQUE_CARRIER': 'WN', 'TAIL_NUM': 'N7864B', 'OP_CARRIER_FL_NUM': 398, 'ORIGIN_AIRPORT_ID': 11278, 'DEST_AIRPORT_ID': 10397, 'CRS_DEP_TIME': 600, 'DEP_TIME': 600, 'DEP_DELAY_NEW': 0, 'DEP_TIME_BLK': '0600-0659', 'CRS_ARR_TIME': 800, 'ARR_TIME': 750, 'ARR_DELAY_NEW': 0, 'ARR_TIME_BLK': '0800-0859', 'CANCELLED': 0, 'CRS_ELAPSED_TIME': 120, 'ACTUAL_ELAPSED_TIME': 110, 'DISTANCE': 547, 'DISTANCE_GROUP': 3, 'YEAR': 2019}, {'MONTH': 1, 'DAY_OF_MONTH': 20, 'DAY_OF_WEEK': 7, 'OP_UNIQUE_CARRIER': 'WN', 'TAIL_NUM': 'N928WN', 'OP_CARRIER_FL_NUM': 1294, 'ORIGIN_AIRPORT_ID': 11278, 'DEST_AIRPORT_ID': 10397, 'CRS_DEP_TIME': 1040, 'DEP_TIME': 1041, 'DEP_DELAY_NEW': 1, 'DEP_TIME_BLK': '1000-1059', 'CRS_ARR_TIME': 1245, 'ARR_TIME': 1222, 'ARR_DELAY_NEW': 0, 'ARR_TIME_BLK': '1200-1259', 'CANCELLED': 0, 'CRS_ELAPSED_TIME': 125, 'ACTUAL_ELAPSED_TIME': 101, 'DISTANCE': 547, 'DISTANCE_GROUP': 3, 'YEAR': 2019}, {'MONTH': 1, 'DAY_OF_MONTH': 20, 'DAY_OF_WEEK': 7, 'OP_UNIQUE_CARRIER': 'WN', 'TAIL_NUM': 'N455WN', 'OP_CARRIER_FL_NUM': 4175, 'ORIGIN_AIRPORT_ID': 11278, 'DEST_AIRPORT_ID': 10397, 'CRS_DEP_TIME': 1630, 'DEP_TIME': 1626, 'DEP_DELAY_NEW': 0, 'DEP_TIME_BLK': '1600-1659', 'CRS_ARR_TIME': 1830, 'ARR_TIME': 1810, 'ARR_DELAY_NEW': 0, 'ARR_TIME_BLK': '1800-1859', 'CANCELLED': 0, 'CRS_ELAPSED_TIME': 120, 'ACTUAL_ELAPSED_TIME': 104, 'DISTANCE': 547, 'DISTANCE_GROUP': 3, 'YEAR': 2019}, {'MONTH': 1, 'DAY_OF_MONTH': 20, 'DAY_OF_WEEK': 7, 'OP_UNIQUE_CARRIER': 'WN', 'TAIL_NUM': 'N474WN', 'OP_CARRIER_FL_NUM': 4338, 'ORIGIN_AIRPORT_ID': 11278, 'DEST_AIRPORT_ID': 10397, 'CRS_DEP_TIME': 2120, 'DEP_TIME': 2113, 'DEP_DELAY_NEW': 0, 'DEP_TIME_BLK': '2100-2159', 'CRS_ARR_TIME': 2315, 'ARR_TIME': 2251, 'ARR_DELAY_NEW': 0, 'ARR_TIME_BLK': '2300-2359', 'CANCELLED': 0, 'CRS_ELAPSED_TIME': 115, 'ACTUAL_ELAPSED_TIME': 98, 'DISTANCE': 547, 'DISTANCE_GROUP': 3, 'YEAR': 2019}, {'MONTH': 1, 'DAY_OF_MONTH': 5, 'DAY_OF_WEEK': 6, 'OP_UNIQUE_CARRIER': 'WN', 'TAIL_NUM': 'N250WN', 'OP_CARRIER_FL_NUM': 2905, 'ORIGIN_AIRPORT_ID': 11278, 'DEST_AIRPORT_ID': 10397, 'CRS_DEP_TIME': 605, 'DEP_TIME': 601, 'DEP_DELAY_NEW': 0, 'DEP_TIME_BLK': '0600-0659', 'CRS_ARR_TIME': 805, 'ARR_TIME': 740, 'ARR_DELAY_NEW': 0, 'ARR_TIME_BLK': '0800-0859', 'CANCELLED': 0, 'CRS_ELAPSED_TIME': 120, 'ACTUAL_ELAPSED_TIME': 99, 'DISTANCE': 547, 'DISTANCE_GROUP': 3, 'YEAR': 2019}]

# %%
# pętla dla 2 lotnisk - sprawdzimy działanie ze sleep
# 12264	Washington Dulles International
# 11278	Ronald Reagan Washington National

airports_to_test = ['11278', '12264']
test_list = []
for var in airports_to_test:
    test_response = one_airport_loop(var)
    sleep(5)
    if test_response != None:
        test_list.extend(test_response)
    print(datetime.datetime.now(), "Przechodzę do następnego lotniska")
# Out:
# 2024-03-07 09:20:29.046165  Pobrano dane dla lotniska o id: 11278 w miesiącu 2019-01-01
# 2024-03-07 09:20:31.147019  Pobrano dane dla lotniska o id: 11278 w miesiącu 2019-02-01
# 2024-03-07 09:20:33.287531  Pobrano dane dla lotniska o id: 11278 w miesiącu 2019-03-01
# 2024-03-07 09:20:35.422066  Pobrano dane dla lotniska o id: 11278 w miesiącu 2019-04-01
# 2024-03-07 09:20:37.567180  Pobrano dane dla lotniska o id: 11278 w miesiącu 2019-05-01
# 2024-03-07 09:20:39.667473  Pobrano dane dla lotniska o id: 11278 w miesiącu 2019-06-01
# 2024-03-07 09:20:41.868439  Pobrano dane dla lotniska o id: 11278 w miesiącu 2019-07-01
# 2024-03-07 09:20:43.902792  Pobrano dane dla lotniska o id: 11278 w miesiącu 2019-08-01
# 2024-03-07 09:20:46.104651  Pobrano dane dla lotniska o id: 11278 w miesiącu 2019-09-01
# 2024-03-07 09:20:48.283157  Pobrano dane dla lotniska o id: 11278 w miesiącu 2019-10-01
# 2024-03-07 09:20:50.338705  Pobrano dane dla lotniska o id: 11278 w miesiącu 2019-11-01
# 2024-03-07 09:20:52.355764  Pobrano dane dla lotniska o id: 11278 w miesiącu 2019-12-01
# 2024-03-07 09:20:54.452267  Pobrano dane dla lotniska o id: 11278 w miesiącu 2020-01-01
# 2024-03-07 09:20:56.544213  Pobrano dane dla lotniska o id: 11278 w miesiącu 2020-02-01
# 2024-03-07 09:20:58.623167  Pobrano dane dla lotniska o id: 11278 w miesiącu 2020-03-01
# 2024-03-07 09:20:58.634281 Koniec zadania dla lotniska 11278
# 2024-03-07 09:21:03.635004 Przechodzę do następnego lotniska
# 2024-03-07 09:21:04.898267  Brak danych dla lotniska o id: 12264 w miesiącu 2019-01-01
# 2024-03-07 09:21:06.207202  Brak danych dla lotniska o id: 12264 w miesiącu 2019-02-01
# 2024-03-07 09:21:07.532257  Brak danych dla lotniska o id: 12264 w miesiącu 2019-03-01
# 2024-03-07 09:21:08.836685  Brak danych dla lotniska o id: 12264 w miesiącu 2019-04-01
# 2024-03-07 09:21:10.125042  Brak danych dla lotniska o id: 12264 w miesiącu 2019-05-01
# 2024-03-07 09:21:11.585579  Brak danych dla lotniska o id: 12264 w miesiącu 2019-06-01
# 2024-03-07 09:21:13.225184  Brak danych dla lotniska o id: 12264 w miesiącu 2019-07-01
# 2024-03-07 09:21:14.605123  Brak danych dla lotniska o id: 12264 w miesiącu 2019-08-01
# 2024-03-07 09:21:15.944334  Brak danych dla lotniska o id: 12264 w miesiącu 2019-09-01
# 2024-03-07 09:21:17.271272  Brak danych dla lotniska o id: 12264 w miesiącu 2019-10-01
# 2024-03-07 09:21:18.583886  Brak danych dla lotniska o id: 12264 w miesiącu 2019-11-01
# 2024-03-07 09:21:19.880913  Brak danych dla lotniska o id: 12264 w miesiącu 2019-12-01
# 2024-03-07 09:21:21.273889  Brak danych dla lotniska o id: 12264 w miesiącu 2020-01-01
# 2024-03-07 09:21:22.571343  Brak danych dla lotniska o id: 12264 w miesiącu 2020-02-01
# 2024-03-07 09:21:23.949815  Brak danych dla lotniska o id: 12264 w miesiącu 2020-03-01
# 2024-03-07 09:21:23.951804 Koniec zadania dla lotniska 12264
# 2024-03-07 09:21:28.952464 Przechodzę do następnego lotniska

# %%
len(test_list)  # wynik z pustą listą 38354
# Out:
# 38354

# %%
output_list = []
for airport_id in airports_list:
    test_response = one_airport_loop(airport_id)
    sleep(5)
    if test_response != None:
        output_list.extend(test_response)
    print(datetime.datetime.now(), "Przechodzę do następnego lotniska")
 
# with open(r'..\data\raw\temp_flights.csv', "w", newline="") as plik:  #zabezpieczenie ;)
#   writer = csv.writer(plik)
#   writer.writerows(output_list)
# Out:
# 2024-03-07 09:23:42.050096  Brak danych dla lotniska o id: 10874 w miesiącu 2019-01-01
# 2024-03-07 09:23:43.377732  Brak danych dla lotniska o id: 10874 w miesiącu 2019-02-01
# 2024-03-07 09:23:44.691701  Brak danych dla lotniska o id: 10874 w miesiącu 2019-03-01
# 2024-03-07 09:23:45.982767  Brak danych dla lotniska o id: 10874 w miesiącu 2019-04-01
# 2024-03-07 09:23:47.375014  Brak danych dla lotniska o id: 10874 w miesiącu 2019-05-01
# 2024-03-07 09:23:48.584128  Brak danych dla lotniska o id: 10874 w miesiącu 2019-06-01
# 2024-03-07 09:23:49.860903  Brak danych dla lotniska o id: 10874 w miesiącu 2019-07-01
# 2024-03-07 09:23:51.127535  Brak danych dla lotniska o id: 10874 w miesiącu 2019-08-01
# 2024-03-07 09:23:52.643370  Brak danych dla lotniska o id: 10874 w miesiącu 2019-09-01
# 2024-03-07 09:23:53.972391  Brak danych dla lotniska o id: 10874 w miesiącu 2019-10-01
# 2024-03-07 09:23:55.279142  Brak danych dla lotniska o id: 10874 w miesiącu 2019-11-01
# 2024-03-07 09:23:56.620343  Brak danych dla lotniska o id: 10874 w miesiącu 2019-12-01
# 2024-03-07 09:23:57.904051  Brak danych dla lotniska o id: 10874 w miesiącu 2020-01-01
# 2024-03-07 09:23:59.238268  Brak danych dla lotniska o id: 10874 w miesiącu 2020-02-01
# 2024-03-07 09:24:00.596724  Brak danych dla lotniska o id: 10874 w miesiącu 2020-03-01
# 2024-03-07 09:24:00.597714 Koniec zadania dla lotniska 10874
# 2024-03-07 11:58:57.066441 Koniec zadania dla lotniska 12945
# 2024-03-07 11:59:02.067387 Przechodzę do następnego lotniska
# 2024-03-07 11:59:03.304139  Brak danych dla lotniska o id: 12511 w miesiącu 2019-01-01
# 2024-03-07 11:59:04.659825  Brak danych dla lotniska o id: 12511 w miesiącu 2019-02-01
# 2024-03-07 11:59:05.969000  Brak danych dla lotniska o id: 12511 w miesiącu 2019-03-01
# 2024-03-07 11:59:07.306216  Brak danych dla lotniska o id: 12511 w miesiącu 2019-04-01
# 2024-03-07 11:59:08.635171  Brak danych dla lotniska o id: 12511 w miesiącu 2019-05-01
# 2024-03-07 11:59:09.972241  Brak danych dla lotniska o id: 12511 w miesiącu 2019-06-01
# 2024-03-07 11:59:11.385191  Brak danych dla lotniska o id: 12511 w miesiącu 2019-07-01
# 2024-03-07 11:59:12.642408  Brak danych dla lotniska o id: 12511 w miesiącu 2019-08-01
# 2024-03-07 11:59:13.873094  Brak danych dla lotniska o id: 12511 w miesiącu 2019-09-01
# 2024-03-07 11:59:15.184577  Brak danych dla lotniska o id: 12511 w miesiącu 2019-10-01
# 2024-03-07 11:59:16.534337  Brak danych dla lotniska o id: 12511 w miesiącu 2019-11-01
# 2024-03-07 11:59:17.907646  Brak danych dla lotniska o id: 12511 w miesiącu 2019-12-01
# 2024-03-07 11:59:19.290151  Brak danych dla lotniska o id: 12511 w miesiącu 2020-01-01
# 2024-03-07 11:59:20.647165  Brak danych dla lotniska o id: 12511 w miesiącu 2020-02-01
# 2024-03-07 11:59:21.964534  Brak danych dla lotniska o id: 12511 w miesiącu 2020-03-01
# 2024-03-07 11:59:21.966038 Koniec zadania dla lotniska 12511
# 2024-03-07 11:59:26.966563 Przechodzę do następnego lotniska

# %%
len(output_list)
# Out:
# 1386120

# %%
flight_df = pd.DataFrame(output_list)

# %%
# ##Zapis poprawnych danych, bo wczesniej ccos ci nie wyszlo
# keys = output_list[0].keys()
# with open(r'..\data\raw\temp_flights_by_piotr.csv', 'w', newline='') as output_file:
#     dict_writer = csv.DictWriter(output_file, fieldnames=keys,extrasaction='ignore', delimiter = ';')
#     dict_writer.writeheader()
#     dict_writer.writerows(output_list)

# %% [markdown]
#  ## Sprawdzenie
#  Uruchom kod poniżej, aby sprawdzić, czy ta część została poprawnie wykonana

# %%
flight_df_expected_shape = (1386120, 27)
assert flight_df_expected_shape == flight_df.shape

# %% [markdown]
#  ## Zapis do pliku
#  Tutaj zapisz ramkę `flight_df` do pliku `flight.csv` w katalogu `data/raw`

# %%
flight_df.to_csv(r'..\data\raw\flight.csv', index=False)

# %% [markdown]
#  # Podsumowanie
#  W tym notatniku wykonaliśmy podstawowy krok w analizie danych - pozyskaliśmy je. Są gotowe do dalszej pracy, czyli możemy załadować je na bazę danych, a następnie zapoznać się z tym, jakie informacje ze sobą niosą. Kolejne notatniki będą służyły właśnie tym celom.

# %%
msg = "Wszystko wygląda OK :) Możesz przejść do kolejnego kroku."
print(msg)
# Out:
# Wszystko wygląda OK :) Możesz przejść do kolejnego kroku.
